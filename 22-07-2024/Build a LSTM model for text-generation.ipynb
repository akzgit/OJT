# %%
#importing the libraries
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
#prepare the data
data = """Text generation is the task of generating meaningful text given a sequence of text as input.
It is widely used in applications such as chatbots, language translation, and text summarization.
Generating text requires a model to learn the patterns and structure of the input text to produce coherent and contextually relevant output."""

# %%
#Tokenize the text
tokenizer = Tokenizer() # create a vocabulary
tokenizer.fit_on_texts([data])
total_words = len(tokenizer.word_index) + 1  # +1 for the reserved 0 index

# Convert text to sequences of integers
input_sequences = []
for line in data.split('.'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
# Pad sequences to ensure they are of the same length
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

# Create predictors and labels
predictors, label = input_sequences[:,:-1], input_sequences[:,-1]
label = to_categorical(label, num_classes=total_words)

# %%
#build the LSTM model
model = Sequential()
model.add(Embedding(total_words, 10))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.fit(predictors, label, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 29ms/step - loss: 3.5836
# Epoch 2/100
# 2/2 [==============================] - 0s 18ms/step - loss: 3.5791
# Epoch 3/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.5747
# Epoch 4/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.5709
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 3.5656
# Epoch 6/100
# 2/2 [==============================] - 0s 15ms/step - loss: 3.5578
# Epoch 7/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.5475
# Epoch 8/100
# 2/2 [==============================] - 0s 13ms/step - loss: 3.5286
# Epoch 9/100
# 2/2 [==============================] - 0s 17ms/step - loss: 3.5012
# Epoch 10/100
# 2/2 [==============================] - 0s 13ms/step - loss: 3.4710
# Epoch 11/100
# 2/2 [==============================] - 0s 13ms/step - loss: 3.4245
# Epoch 12/100
# 2/2 [==============================] - 0s 13ms/step - loss: 3.4186
# Epoch 13/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.4092
# Epoch 14/100
# 2/2 [==============================] - 0s 8ms/step - loss: 3.3874
# Epoch 15/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.3834
# Epoch 16/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.3858
# Epoch 17/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.3838
# Epoch 18/100
# 2/2 [==============================] - 0s 11ms/step - loss: 3.3725
# Epoch 19/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.3569
# Epoch 20/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.3449
# Epoch 21/100
# 2/2 [==============================] - 0s 15ms/step - loss: 3.3334
# Epoch 22/100
# 2/2 [==============================] - 0s 16ms/step - loss: 3.3188
# Epoch 23/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.2956
# Epoch 24/100
# 2/2 [==============================] - 0s 14ms/step - loss: 3.2564
# Epoch 25/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.2306
# Epoch 26/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.1926
# Epoch 27/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.1720
# Epoch 28/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.1220
# Epoch 29/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.1355
# Epoch 30/100
# 2/2 [==============================] - 0s 9ms/step - loss: 3.0637
# Epoch 31/100
# 2/2 [==============================] - 0s 12ms/step - loss: 3.0556
# Epoch 32/100
# 2/2 [==============================] - 0s 10ms/step - loss: 3.0023
# Epoch 33/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.9834
# Epoch 34/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9428
# Epoch 35/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.9232
# Epoch 36/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9741
# Epoch 37/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.9851
# Epoch 38/100
# 2/2 [==============================] - 0s 6ms/step - loss: 3.0805
# Epoch 39/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.8606
# Epoch 40/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.9292
# Epoch 41/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.8322
# Epoch 42/100
# 2/2 [==============================] - 0s 0s/step - loss: 2.8310
# Epoch 43/100
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8258
# Epoch 44/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.7713
# Epoch 45/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.7680
# Epoch 46/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.7164
# Epoch 47/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.7107
# Epoch 48/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.7105
# Epoch 49/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6534
# Epoch 50/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6633
# Epoch 51/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6312
# Epoch 52/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.6167
# Epoch 53/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.5702
# Epoch 54/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.5785
# Epoch 55/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.5531
# Epoch 56/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.5236
# Epoch 57/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.5211
# Epoch 58/100
# 2/2 [==============================] - 0s 17ms/step - loss: 2.5011
# Epoch 59/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.4855
# Epoch 60/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4828
# Epoch 61/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.4294
# Epoch 62/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4363
# Epoch 63/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.4313
# Epoch 64/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4064
# Epoch 65/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.3793
# Epoch 66/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.3508
# Epoch 67/100
# 2/2 [==============================] - 0s 13ms/step - loss: 2.3218
# Epoch 68/100
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3038
# Epoch 69/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2910
# Epoch 70/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2712
# Epoch 71/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2563
# Epoch 72/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.2376
# Epoch 73/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2231
# Epoch 74/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2059
# Epoch 75/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.2007
# Epoch 76/100
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1928
# Epoch 77/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1647
# Epoch 78/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1803
# Epoch 79/100
# 2/2 [==============================] - 0s 11ms/step - loss: 2.1953
# Epoch 80/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2360
# Epoch 81/100
# 2/2 [==============================] - 0s 10ms/step - loss: 2.1219
# Epoch 82/100
# 2/2 [==============================] - 0s 12ms/step - loss: 2.1061
# Epoch 83/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.2023
# Epoch 84/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1257
# Epoch 85/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0947
# Epoch 86/100
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0636
# Epoch 87/100
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0514
# Epoch 88/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0378
# Epoch 89/100
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0468
# Epoch 90/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0248
# Epoch 91/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0054
# Epoch 92/100
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0405
# Epoch 93/100
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0461
# Epoch 94/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9815
# Epoch 95/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9764
# Epoch 96/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9606
# Epoch 97/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9326
# Epoch 98/100
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9388
# Epoch 99/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.9201
# Epoch 100/100
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9003

# %%
def generate_text(seed_text, next_words, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1) # find the index of the word with the highest probality
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_word_index:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

seed_text = "AI"
generated_text = generate_text(seed_text, 20, max_sequence_len)
print(generated_text)
# Out:
# AI is is is is the the the the and and and of text text input to produce coherent and contextually
